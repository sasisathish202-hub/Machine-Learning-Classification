# %%
import pickle

# %%
loaded_model = pickle.load(open("finalized_DecisionTree_cls.sav", 'rb'))
result = loaded_model.predict([[23,150000,1]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([1])
