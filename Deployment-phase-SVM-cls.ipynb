# %%
import pickle

# %%
loaded_model = pickle.load(open("finalized_SVM.cls.sav", 'rb'))
result = loaded_model.predict([[23,54000,1]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([0])
